# %% [markdown]
# # Import Necessary Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing Dataset

# %%
data = pd.read_csv('Grades.csv')

# %%
data
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %%
data.head(10)
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
# 5  CS-97006      A     B-      B        D+     C+     A-     C+      B     B+
# 6  CS-97007     B-     C-     A-         D     A-      B      A     B+     A-
# 7  CS-97008     B+     B+     C+         C      C     A-     C-     A-      B
# 8  CS-97009     A-      C     A-        D+      B     A-     A-     A-     B+
# 9  CS-97010      A      B     C+         B      B     A-      C     B-     A-
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# ...

# %%
data.tail(10)
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 561  CS-97562     B-      B     A-        B+     B-     B+     A-      A
# 562  CS-97563      B      B      A         C      B     B+      B     C-
# 563  CS-97564     A-      B      A        D+     B+     A-      C      A
# 564  CS-97565     A-      D      A         C     B+     B+      C     A-
# 565  CS-97566      F      F      D        C-    NaN     D+      D    NaN
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 561      B  ...     B+     B-     B+     D+     C+     B-     B+      C
# ...

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
#checking the dimension of data
data.shape
# Out:
# (571, 43)

# %%
data.columns
# Out:
# Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412', 'CGPA'],
#       dtype='object')

# %%
#checking the columns of dataset
data.columns.tolist()
# Out:
# ['Seat No.',
#  'PH-121',
#  'HS-101',
#  'CY-105',
#  'HS-105/12',
#  'MT-111',
#  'CS-105',
#  'CS-106',
#  'EL-102',
#  'EE-119',
#  'ME-107',
#  'CS-107',
#  'HS-205/20',
#  'MT-222',
#  'EE-222',
#  'MT-224',
#  'CS-210',
#  'CS-211',
#  'CS-203',
#  'CS-214',
#  'EE-217',
#  'CS-212',
#  'CS-215',
#  'MT-331',
#  'EF-303',
#  'HS-304',
#  'CS-301',
#  'CS-302',
#  'TC-383',
#  'MT-442',
#  'EL-332',
#  'CS-318',
#  'CS-306',
#  'CS-312',
#  'CS-317',
#  'CS-403',
#  'CS-421',
#  'CS-406',
#  'CS-414',
#  'CS-419',
#  'CS-423',
#  'CS-412',
#  'CGPA']

# %%
#checking the types of columns
data.dtypes
# Out:
# Seat No.      object
# PH-121        object
# HS-101        object
# CY-105        object
# HS-105/12     object
# MT-111        object
# CS-105        object
# CS-106        object
# EL-102        object
# EE-119        object
# ME-107        object
# CS-107        object
# HS-205/20     object
# MT-222        object
# EE-222        object
# MT-224        object
# CS-210        object
# CS-211        object
# CS-203        object
# CS-214        object
# EE-217        object
# CS-212        object
# CS-215        object
# MT-331        object
# EF-303        object
# HS-304        object
# CS-301        object
# CS-302        object
# TC-383        object
# MT-442        object
# EL-332        object
# CS-318        object
# CS-306        object
# CS-312        object
# CS-317        object
# CS-403        object
# CS-421        object
# CS-406        object
# CS-414        object
# CS-419        object
# CS-423        object
# CS-412        object
# CGPA         float64
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     570 non-null    object
#  4   HS-105/12  570 non-null    object
#  5   MT-111     569 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     569 non-null    object
#  8   EL-102     569 non-null    object
#  9   EE-119     569 non-null    object
#  10  ME-107     569 non-null    object
#  11  CS-107     569 non-null    object
#  12  HS-205/20  566 non-null    object
#  13  MT-222     566 non-null    object
#  14  EE-222     564 non-null    object
#  15  MT-224     564 non-null    object
#  16  CS-210     564 non-null    object
#  17  CS-211     566 non-null    object
#  18  CS-203     566 non-null    object
# ...

# %%
data.isnull().sum().sum()
# Out:
# 425

# %%
data.isnull().sum()
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %%
#lets visualize it using heatmap
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.replace(np.nan,0, inplace = True)
data.head(10)
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
# 5  CS-97006      A     B-      B        D+     C+     A-     C+      B     B+
# 6  CS-97007     B-     C-     A-         D     A-      B      A     B+     A-
# 7  CS-97008     B+     B+     C+         C      C     A-     C-     A-      B
# 8  CS-97009     A-      C     A-        D+      B     A-     A-     A-     B+
# 9  CS-97010      A      B     C+         B      B     A-      C     B-     A-
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# ...

# %%
data.isnull().sum()
# Out:
# Seat No.     0
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %%
#checking the value counts of each column
for i in data.columns:
    print(data[i].value_counts())
    print("\n")
# Out:
# CS-97143    1
# CS-97363    1
# CS-97386    1
# CS-97352    1
# CS-97051    1
#            ..
# CS-97298    1
# CS-97086    1
# CS-97067    1
# CS-97412    1
# CS-97172    1
# Name: Seat No., Length: 571, dtype: int64
#
#
# A-    112
# A     111
# B+     61
# B      57
# B-     56
# D      44
# C      33
# C+     31
# D+     22
# A+     22
# C-     19
# WU      2
# F       1
# Name: PH-121, dtype: int64
#
#
# A-    82
# B-    78
# C     68
# B     63
# B+    59
# C-    50
# C+    47
# D     45
# A     38
# D+    36
# A+     4
# F      1
# Name: HS-101, dtype: int64
#
#
# A     177
# A-    120
# B+     50
# B      49
# B-     42
# D      31
# A+     31
# C      19
# C+     17
# C-     16
# D+     14
# WU      3
# F       1
# 0       1
# Name: CY-105, dtype: int64
#
#
# A     96
# A-    75
# B+    70
# B     57
# D     45
# C     41
# B-    40
# C+    39
# C-    36
# D+    34
# A+    34
# WU     2
# F      1
# 0      1
# Name: HS-105/12, dtype: int64
#
#
# A-    105
# A     100
# ...

# %%
data.shape[0]
# Out:
# 571

# %%
#Separating Numerical and Categorical columns

#Checking for categorical columns
categorical_col = []
for i in data.dtypes.index:
    if data.dtypes[i] == "object":
        categorical_col.append(i)
        
print("Categorical Columns: ", categorical_col)
print("\n")

#Checking for Numerical columns
numerical_col = []
for i in data.dtypes.index:
    if data.dtypes[i]!= "object":
        numerical_col.append(i)
        
print("Numerical Columns: ", numerical_col)
print("\n")
# Out:
# Categorical Columns:  ['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20', 'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214', 'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301', 'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312', 'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423', 'CS-412']
#
#
# Numerical Columns:  ['CGPA']

# %%
# Checking number of unique values in each column
data.nunique().to_frame("No. of unique values")
# Out:
#            No. of unique values
# Seat No.                    571
# PH-121                       13
# HS-101                       12
# CY-105                       14
# HS-105/12                    14
# MT-111                       14
# CS-105                       11
# CS-106                       14
# EL-102                       14
# EE-119                       13
# ME-107                       14
# CS-107                       15
# HS-205/20                    14
# MT-222                       15
# EE-222                       14
# MT-224                       15
# CS-210                       15
# CS-211                       15
# CS-203                       14
# CS-214                       14
# EE-217                       14
# CS-212                       13
# CS-215                       15
# MT-331                       13
# EF-303                       13
# HS-304                       15
# CS-301                       13
# CS-302                       12
# ...

# %% [markdown]
# # Desciption of Dataset

# %%
# Statistical summary of numerical column
data.describe()
# Out:
#              CGPA
# count  571.000000
# mean     2.954888
# std      0.620552
# min      0.800000
# 25%      2.538000
# 50%      3.029000
# 75%      3.451000
# max      3.985000

# %%
input = data.drop(["CS-403","CS-421","CS-406","CS-414","CS-419","CS-423","CS-412", 'MT-442',"Seat No.","CGPA"], axis=1)
target = data[["CGPA"]]

# %%
target.head()
# Out:
#     CGPA
# 0  2.205
# 1  2.008
# 2  3.608
# 3  1.906
# 4  3.448

# %%
pd.unique(data["PH-121"])
# Out:
# array(['B-', 'A', 'D', 'A-', 'B+', 'B', 'C+', 'C', 'C-', 'D+', 'WU', 'A+',
#        'F'], dtype=object)

# %%
grades_enc = {'B-':2.7, 'A':4, 'D':1.0, 'A-':3.7, 'B+':3.4, 'B':3.0, 'C+':2.4, 'C':2.0, 'C-':1.7, 'D+':1.4, 'WU':0.0, 'A+':4,'F':0.0,'W':0,'I':0}

# %%
type(input)
# Out:
# pandas.core.frame.DataFrame

# %%
for item in input:
      input[item] = input[item].replace(grades_enc)

input.head()
# Out:
#    PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  EE-119  \
# 0     2.7     1.4     1.7        2.0     1.7     1.4     1.0     1.7     2.7
# 1     4.0     1.0     1.4        1.0     2.7     2.0     1.0     4.0     1.4
# 2     4.0     3.0     4.0        2.7     3.4     4.0     2.7     3.4     3.7
# 3     1.0     2.4     1.4        1.0     1.0     3.7     1.4     1.7     1.0
# 4     3.7     3.7     3.7        3.4     4.0     4.0     3.7     3.4     4.0
#
#    ME-107  ...  EF-303  HS-304  CS-301  CS-302  TC-383  EL-332  CS-318  \
# 0     1.7  ...     1.7     2.4     3.0     2.0     2.4     2.0     1.7
# 1     1.0  ...     1.0     1.7     3.7     1.4     1.7     2.0     3.7
# 2     3.7  ...     2.4     4.0     3.4     3.7     3.0     3.4     3.7
# 3     2.4  ...     1.0     2.7     1.0     2.7     1.4     1.4     3.4
# 4     3.7  ...     1.7     3.7     2.7     3.7     2.4     3.7     2.7
#
#    CS-306  CS-312  CS-317
# 0     2.0     1.7     1.7
# ...

# %%
# Concating inputs and targets for data insights
df = pd.concat([input, target], axis=1)

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Univariat Analysis

# %%
df.hist(bins=30,figsize=(30,15))
plt.show()

# %%
#Separating Numerical and Categorical columns

#Checking for categorical columns
categorical_col = []
for i in df.dtypes.index:
    if df.dtypes[i] == "object":
        categorical_col.append(i)
        
print("Categorical Columns: ", categorical_col)
print("\n")

#Checking for Numerical columns
numerical_col = []
for i in df.dtypes.index:
    if df.dtypes[i]!= "object":
        numerical_col.append(i)
        
print("Numerical Columns: ", numerical_col)
print("\n")
# Out:
# Categorical Columns:  []
#
#
# Numerical Columns:  ['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20', 'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214', 'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301', 'CS-302', 'TC-383', 'EL-332', 'CS-318', 'CS-306', 'CS-312', 'CS-317', 'CGPA']

# %%
#let's check how the data has been distributed in remaining column
from socket import socket
plt.figure(figsize = (100, 50), facecolor = "white")
plotnumber = 1
for col in numerical_col:
    if plotnumber<=34:
        ax = plt.subplot(4, 10, plotnumber)
        sns.distplot(df[col], color = "m")
        plt.xlabel(col, fontsize = 12)
        plt.yticks(rotation = 0, fontsize = 20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# # Checking for Outliers

# %%
# Lets check the outliers by plotting boxplot

plt.figure(figsize = (10, 6), facecolor = "white")
plotnumber = 1
for col in numerical_col:
    if plotnumber<=34:
        ax = plt.subplot(4, 10, plotnumber)
        sns.boxplot(df[col], palette = "Set2_r")
        plt.xlabel(col, fontsize = 15)
        plt.yticks(rotation = 0, fontsize = 10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# # Checking for skweness

# %%
df.skew()
# Out:
# PH-121      -0.883809
# HS-101      -0.227717
# CY-105      -1.405404
# HS-105/12   -0.599766
# MT-111      -0.863246
# CS-105      -1.274883
# CS-106      -1.013401
# EL-102      -0.853111
# EE-119      -0.857386
# ME-107      -0.399327
# CS-107      -0.673185
# HS-205/20   -1.760646
# MT-222      -0.430584
# EE-222      -1.203849
# MT-224      -0.753516
# CS-210      -1.245586
# CS-211      -0.388519
# CS-203      -0.616304
# CS-214      -0.251505
# EE-217      -1.216911
# CS-212      -0.715871
# CS-215      -0.440605
# MT-331      -1.029391
# EF-303      -0.580085
# HS-304      -0.930804
# CS-301      -0.806083
# CS-302      -1.263406
# TC-383      -0.669712
# EL-332      -0.917194
# CS-318      -0.701601
# CS-306      -0.899600
# CS-312      -0.631603
# CS-317      -0.625574
# CGPA        -0.497203
# dtype: float64

# %% [markdown]
# # Removing Skweness

# %%
# Removing skewness using cuberoot method
df['PH-121'] = np.cbrt(df['PH-121'])
df['CY-105'] = np.cbrt(df['CY-105'])
df['MT-111'] = np.cbrt(df['MT-111'])
df['CS-105Ω'] = np.cbrt(df['CS-105'])
df['CS-106'] = np.cbrt(df['CS-106'])
df['EL-102'] = np.cbrt(df['EL-102'])
df['EE-119'] = np.cbrt(df['EE-119'])
df['CS-107'] = np.cbrt(df['CS-107'])
df['HS-205/20'] = np.cbrt(df['HS-205/20'])
df['EE-222'] = np.cbrt(df['EE-222'])
df['MT-224'] = np.cbrt(df['MT-224'])
df['MT-331'] = np.cbrt(df['MT-331'])
df['HS-304'] = np.cbrt(df['HS-304'])
df['CS-301'] = np.cbrt(df['CS-301'])
df['CS-302'] = np.cbrt(df['CS-302'])
df['TC-383'] = np.cbrt(df['TC-383'])
df['EL-332'] = np.cbrt(df['EL-332'])
df['CS-318'] = np.cbrt(df['CS-318'])
df['CS-306'] = np.cbrt(df['CS-306'])
df['CS-312'] = np.cbrt(df['CS-312'])
df['CS-317'] = np.cbrt(df['CS-317'])
df['CS-318'] = np.cbrt(df['CS-318'])

# %%
# checking skweness again
df.skew()
# Out:
# PH-121      -8.714168
# HS-101      -0.227717
# CY-105      -3.515397
# HS-105/12   -0.599766
# MT-111      -3.269224
# CS-105      -1.274883
# CS-106      -3.431357
# EL-102      -2.939251
# EE-119      -3.217368
# ME-107      -0.399327
# CS-107      -2.617176
# HS-205/20   -5.254155
# MT-222      -0.430584
# EE-222      -3.505613
# MT-224      -3.040500
# CS-210      -1.245586
# CS-211      -0.388519
# CS-203      -0.616304
# CS-214      -0.251505
# EE-217      -1.216911
# CS-212      -0.715871
# CS-215      -0.440605
# MT-331      -3.347417
# EF-303      -0.580085
# HS-304      -3.337240
# CS-301      -3.256928
# CS-302      -4.021476
# TC-383      -3.092905
# EL-332      -3.252998
# CS-318      -4.196788
# CS-306      -3.288291
# CS-312      -2.901361
# CS-317      -3.250174
# CGPA        -0.497203
# CS-105Ω     -1.656495
# dtype: float64

# %%
# Lets visualize how the data has been distributed in PH-121 after removing skewness
sns.distplot(df['PH-121'], color = 'm', kde_kws = {"shade":True}, hist = False)
plt.show()

# %%
# Lets visualize how the data has been distributed in CY-105 after removing skewness
sns.distplot(df['CY-105'], color = 'm', kde_kws = {"shade":True}, hist = False)
plt.show()

# %%
# Lets visualize how the data has been distributed in MT-111 after removing skewness
sns.distplot(df['MT-111'], color = 'm', kde_kws = {"shade":True}, hist = False)
plt.show()

# %%
# Lets visualize how the data has been distributed in CS-105 after removing skewness
sns.distplot(df['CS-105'], color = 'm', kde_kws = {"shade":True}, hist = False)
plt.show()

# %%
# Lets visualize how the data has been distributed in CS-106 after removing skewness
sns.distplot(df['CS-106'], color = 'm', kde_kws = {"shade":True}, hist = False)
plt.show()

# %%
# Lets visualize how the data has been distributed in EL-102 after removing skewness
sns.distplot(df['EL-102'], color = 'm', kde_kws = {"shade":True}, hist = False)
plt.show()

# %%
# Lets visualize how the data has been distributed in EE-119 after removing skewness
sns.distplot(df['EE-119'], color = 'm', kde_kws = {"shade":True}, hist = False)
plt.show()

# %%
# Lets visualize how the data has been distributed in CS-107 after removing skewness
sns.distplot(df['CS-107'], color = 'm', kde_kws = {"shade":True}, hist = False)
plt.show()

# %%
# Lets visualize how the data has been distributed in HS-205/20 after removing skewness
sns.distplot(df['HS-205/20'], color = 'm', kde_kws = {"shade":True}, hist = False)
plt.show()

# %%
# Lets visualize how the data has been distributed in EE-222 after removing skewness
sns.distplot(df['EE-222'], color = 'm', kde_kws = {"shade":True}, hist = False)
plt.show()

# %%
# Lets visualize how the data has been distributed in MT-224 after removing skewness
sns.distplot(df['MT-224'], color = 'm', kde_kws = {"shade":True}, hist = False)
plt.show()

# %%
# Lets visualize how the data has been distributed in MT-331 after removing skewness
sns.distplot(df['MT-331'], color = 'm', kde_kws = {"shade":True}, hist = False)
plt.show()

# %%
# Lets visualize how the data has been distributed in HS-304 after removing skewness
sns.distplot(df['HS-304'], color = 'm', kde_kws = {"shade":True}, hist = False)
plt.show()

# %%
# Lets visualize how the data has been distributed in CS-301 after removing skewness
sns.distplot(df['CS-301'], color = 'm', kde_kws = {"shade":True}, hist = False)
plt.show()

# %%
# Lets visualize how the data has been distributed in CS-302 after removing skewness
sns.distplot(df['CS-302'], color = 'm', kde_kws = {"shade":True}, hist = False)
plt.show()

# %%
# Lets visualize how the data has been distributed in TC-383 after removing skewness
sns.distplot(df['CY-105'], color = 'm', kde_kws = {"shade":True}, hist = False)
plt.show()

# %%
# Lets visualize how the data has been distributed in CY-105 after removing skewness
sns.distplot(df['TC-383'], color = 'm', kde_kws = {"shade":True}, hist = False)
plt.show()

# %%
# Lets visualize how the data has been distributed in EL-332 after removing skewness
sns.distplot(df['EL-332'], color = 'm', kde_kws = {"shade":True}, hist = False)
plt.show()

# %%
# Lets visualize how the data has been distributed in CS-318 after removing skewness
sns.distplot(df['CS-318'], color = 'm', kde_kws = {"shade":True}, hist = False)
plt.show()

# %%
# Lets visualize how the data has been distributed in CS-306 after removing skewness
sns.distplot(df['CS-306'], color = 'm', kde_kws = {"shade":True}, hist = False)
plt.show()

# %%
# Lets visualize how the data has been distributed in CS-312 after removing skewness
sns.distplot(df['CS-312'], color = 'm', kde_kws = {"shade":True}, hist = False)
plt.show()

# %%
# Lets visualize how the data has been distributed in CS-317 after removing skewness
sns.distplot(df['CS-317'], color = 'm', kde_kws = {"shade":True}, hist = False)
plt.show()

# %% [markdown]
# # Encoding categorical columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 35 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PH-121     571 non-null    float64
#  1   HS-101     571 non-null    float64
#  2   CY-105     571 non-null    float64
#  3   HS-105/12  571 non-null    float64
#  4   MT-111     571 non-null    float64
#  5   CS-105     571 non-null    float64
#  6   CS-106     571 non-null    float64
#  7   EL-102     571 non-null    float64
#  8   EE-119     571 non-null    float64
#  9   ME-107     571 non-null    float64
#  10  CS-107     571 non-null    float64
#  11  HS-205/20  571 non-null    float64
#  12  MT-222     571 non-null    float64
#  13  EE-222     571 non-null    float64
#  14  MT-224     571 non-null    float64
#  15  CS-210     571 non-null    float64
#  16  CS-211     571 non-null    float64
#  17  CS-203     571 non-null    float64
#  18  CS-214     571 non-null    float64
# ...

# %%
df.describe()
# Out:
#            PH-121      HS-101      CY-105   HS-105/12      MT-111      CS-105  \
# count  571.000000  571.000000  571.000000  571.000000  571.000000  571.000000
# mean     1.117851    2.628371    1.458103    2.878984    1.411027    3.329247
# std      0.095091    0.908402    0.211814    1.019208    0.226318    0.799826
# min      0.000000    0.000000    0.000000    0.000000    0.000000    1.000000
# 25%      1.102163    2.000000    1.392477    2.000000    1.338866    3.000000
# 50%      1.145653    2.700000    1.546680    3.000000    1.503695    3.700000
# 75%      1.156468    3.400000    1.587401    3.700000    1.546680    4.000000
# max      1.166529    4.000000    1.587401    4.000000    1.587401    4.000000
#
#            CS-106      EL-102      EE-119      ME-107  ...      CS-301  \
# count  571.000000  571.000000  571.000000  571.000000  ...  571.000000
# mean     1.412294    1.407540    1.426500    2.698599  ...    1.381647
# ...

# %% [markdown]
# # Correlation between target variable and independent variables.

# %%
# Checking the correlation between features and the target
cor = df.corr()
cor
# Out:
#              PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105  \
# PH-121     1.000000  0.306812  0.518520   0.395291  0.607528  0.500614
# HS-101     0.306812  1.000000  0.296535   0.486628  0.415554  0.432621
# CY-105     0.518520  0.296535  1.000000   0.560182  0.664032  0.560148
# HS-105/12  0.395291  0.486628  0.560182   1.000000  0.511693  0.538699
# MT-111     0.607528  0.415554  0.664032   0.511693  1.000000  0.456693
# CS-105     0.500614  0.432621  0.560148   0.538699  0.456693  1.000000
# CS-106     0.364517  0.311332  0.629940   0.524232  0.662785  0.321689
# EL-102     0.415362  0.348417  0.569939   0.375472  0.628441  0.374579
# EE-119     0.632371  0.309762  0.517793   0.461053  0.465589  0.553951
# ME-107     0.413503  0.366872  0.441340   0.392340  0.461182  0.487723
# CS-107     0.431698  0.449173  0.640992   0.537111  0.604614  0.522374
# HS-205/20  0.447821  0.192605  0.602124   0.279108  0.539353  0.262039
# ...

# %%
# Visualizing the correlation matrix by plotting heatmap
plt.figure(figsize = (20, 15))
sns.heatmap(df.corr(), linewidths = 0.1, fmt = ".1g", linecolor = "black", annot = True, cmap = "Blues_r")
plt.yticks(rotation = 0);
plt.show()

# %%
cor['CGPA'].sort_values(ascending = False)
# Out:
# CGPA         1.000000
# CS-210       0.817242
# CS-215       0.794099
# CS-214       0.786155
# CS-212       0.727184
# EE-217       0.724531
# MT-222       0.711492
# CS-211       0.703034
# MT-111       0.700148
# CS-203       0.698720
# ME-107       0.696306
# CS-301       0.684142
# EL-332       0.675318
# CS-306       0.673126
# HS-105/12    0.671394
# CS-317       0.670252
# MT-224       0.669300
# CS-302       0.644084
# EE-119       0.639431
# TC-383       0.636429
# CS-105       0.627746
# CS-107       0.627566
# EF-303       0.622318
# CS-105Ω      0.618422
# EL-102       0.615160
# CY-105       0.607647
# HS-304       0.591407
# HS-101       0.562432
# EE-222       0.558453
# MT-331       0.557465
# CS-312       0.551975
# CS-106       0.542158
# PH-121       0.512751
# CS-318       0.449041
# HS-205/20    0.448430
# Name: CGPA, dtype: float64

# %% [markdown]
# # Visualizing the correlation between label and features using bar plot

# %%
plt.figure(figsize = (22, 7))
df.corr()['CGPA'].sort_values(ascending = False).drop(['CGPA']).plot(kind = 'bar', color = "m")
plt.xlabel('Feature', fontsize = 15)
plt.ylabel('Target', fontsize = 15)
plt.title("Correlation between label and features using barplot", fontsize = 20)
plt.show()

# %% [markdown]
# # Separating features and label

# %%
x = df.drop("CGPA", axis = 1)
y = df["CGPA"]

# %% [markdown]
# # Feature Scaling using Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns = x.columns)
x
# Out:
#        PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105    CS-106  \
# 0   -0.012313 -1.353419 -1.250399  -0.863175 -0.962074 -2.414197 -2.037964
# 1    0.512353 -1.794139 -1.603822  -1.845189 -0.082038 -1.663377 -2.037964
# 2    0.512353  0.409460  0.610970  -0.175765  0.409816  0.839359 -0.097957
# 3   -1.240434 -0.251619 -1.603822  -1.845189 -1.817742  0.463948 -1.451286
# 4    0.406454  1.180720  0.418553   0.511645  0.780003  0.839359  0.664269
# ..        ...       ...       ...        ...       ...       ...       ...
# 566  0.126091  1.511260  0.610970   0.806249  0.780003  0.839359  0.664269
# 567  0.512353  1.511260  0.610970   1.100853  0.780003  0.839359  0.865551
# 568  0.126091  1.511260  0.418553   0.511645  0.780003  0.839359  0.865551
# 569  0.512353  0.850180 -2.164659   1.100853 -1.817742 -2.414197 -0.097957
# 570 -0.397772 -1.794139 -2.164659  -0.863175 -0.668257 -2.414197  0.148069
#
# ...

# %% [markdown]
# # Checking Variance Inflation Factor(VIF)

# %%
# Finding variance inflation factor in each scaled column i.e, x.shape[1] (1/(1-R2))
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values, i)
                     for i in range(len(x.columns))]
vif["Features"] = x.columns

vif
# Out:
#     VIF values   Features
# 0     2.672868     PH-121
# 1     1.833089     HS-101
# 2     3.335153     CY-105
# 3     2.552746  HS-105/12
# 4     3.772930     MT-111
# 5   101.416624     CS-105
# 6     3.059536     CS-106
# 7     3.065449     EL-102
# 8     2.479534     EE-119
# 9     2.459910     ME-107
# 10    3.041964     CS-107
# 11    3.524265  HS-205/20
# 12    2.457235     MT-222
# 13    3.712763     EE-222
# 14    4.955681     MT-224
# 15    4.581455     CS-210
# 16    2.902195     CS-211
# 17    2.985228     CS-203
# 18    3.029515     CS-214
# 19    3.028573     EE-217
# 20    3.545478     CS-212
# 21    3.390314     CS-215
# 22    3.244488     MT-331
# 23    2.572005     EF-303
# 24    3.668415     HS-304
# 25    6.139542     CS-301
# 26    6.187327     CS-302
# 27    5.307392     TC-383
# 28    3.839976     EL-332
# 29    2.545547     CS-318
# 30    4.545642     CS-306
# 31    4.046614     CS-312
# 32    4.301491     CS-317
# 33   96.718004    CS-105Ω

# %%
# Dropping CS-105 column
x.drop("CS-105", axis = 1, inplace = True)

# %%
# Finding variance inflation factor in each scaled column i.e, x.shape[1] (1/(1-R2))
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values, i)
                     for i in range(len(x.columns))]
vif["Features"] = x.columns

vif
# Out:
#     VIF values   Features
# 0     2.640743     PH-121
# 1     1.832605     HS-101
# 2     3.330815     CY-105
# 3     2.450958  HS-105/12
# 4     3.736067     MT-111
# 5     3.057282     CS-106
# 6     2.996323     EL-102
# 7     2.473806     EE-119
# 8     2.442010     ME-107
# 9     3.013469     CS-107
# 10    3.521672  HS-205/20
# 11    2.454185     MT-222
# 12    3.694520     EE-222
# 13    4.926744     MT-224
# 14    4.555267     CS-210
# 15    2.898735     CS-211
# 16    2.935784     CS-203
# 17    3.027222     CS-214
# 18    3.022245     EE-217
# 19    3.543185     CS-212
# 20    3.366678     CS-215
# 21    3.232331     MT-331
# 22    2.568594     EF-303
# 23    3.668112     HS-304
# 24    6.063351     CS-301
# 25    6.186027     CS-302
# 26    5.299853     TC-383
# 27    3.837282     EL-332
# 28    2.512028     CS-318
# 29    4.532800     CS-306
# 30    4.032024     CS-312
# 31    4.296811     CS-317
# 32    2.364468    CS-105Ω

# %%
y.value_counts()
# Out:
# 3.019    5
# 3.443    3
# 2.756    3
# 2.793    3
# 2.206    3
#         ..
# 2.749    1
# 3.252    1
# 3.664    1
# 3.111    1
# 3.168    1
# Name: CGPA, Length: 491, dtype: int64

# %% [markdown]
# # Modelling

# %% [markdown]
# # Finding the best random state

# %%
# importing necessary libraries:

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
maxAccu = 0
maxRs = 0
for i in range(1, 200):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30, random_state = i)
    LR = LinearRegression()
    LR.fit(x_train, y_train)
    pred = LR.predict(x_test)
    acc = r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRs = i
        
print("Best accuracy is ", maxAccu, "at random state", maxRs)
# Out:
# Best accuracy is  0.9307840072015574 at random state 20

# %% [markdown]
# # Creating train test split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = maxRs)

# %% [markdown]
# # Regression Algorithm

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso, Ridge

# %%
LR = LinearRegression()
LR.fit(x_train, y_train)
pred_LR = LR.predict(x_test)
pred_train = LR.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_LR))
print('R2_score on training data:- ',r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:- ',mean_absolute_error(y_test, pred_LR))
print('Mean Squared Error:- ',mean_squared_error(y_test, pred_LR))
print("Root Mean Squared Error:- ",np.sqrt(mean_squared_error(y_test, pred_LR)))
# Out:
# R2_score:  0.9307840072015574
# R2_score on training data:-  91.52356508284227
# Mean Absolute Error:-  0.12561363379644272
# Mean Squared Error:-  0.029445309211651182
# Root Mean Squared Error:-  0.171596355473102

# %%
plt.figure(figsize=(10,6))
plt.scatter(x = pred_LR, y = y_test, color = 'r')
plt.plot(pred_LR, pred_LR, color = 'b')
plt.xlabel('Actual', fontsize = 14)
plt.ylabel('Predicted', fontsize = 14)
plt.title("Linear Regression", fontsize = 18)
plt.show()

# %%
RFR = RandomForestRegressor()
RFR.fit(x_train, y_train)
pred_RFR = RFR.predict(x_test)
pred_train = RFR.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_RFR))
print('R2_score on training data:- ',r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:- ',mean_absolute_error(y_test, pred_RFR))
print('Mean Squared Error:- ',mean_squared_error(y_test, pred_RFR))
print("Root Mean Squared Error:- ",np.sqrt(mean_squared_error(y_test, pred_RFR)))
# Out:
# R2_score:  0.9567986981189748
# R2_score on training data:-  99.03531379141958
# Mean Absolute Error:-  0.10068895348837205
# Mean Squared Error:-  0.018378349291860434
# Root Mean Squared Error:-  0.13556677060349426

# %%
KNN = KNN()
KNN.fit(x_train, y_train)
pred_KNN = KNN.predict(x_test)
pred_train = KNN.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_KNN))
print('R2_score on training data:- ',r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:- ',mean_absolute_error(y_test, pred_KNN))
print('Mean Squared Error:- ',mean_squared_error(y_test, pred_KNN))
print("Root Mean Squared Error:- ",np.sqrt(mean_squared_error(y_test, pred_KNN)))
# Out:
# R2_score:  0.946718481491363
# R2_score on training data:-  93.58694100428544
# Mean Absolute Error:-  0.11667558139534882
# Mean Squared Error:-  0.02266659372093023
# Root Mean Squared Error:-  0.1505542882847587

# %%
GBR = GradientBoostingRegressor()
GBR.fit(x_train, y_train)
pred_GBR = GBR.predict(x_test)
pred_train = GBR.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_GBR))
print('R2_score on training data:- ',r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:- ',mean_absolute_error(y_test, pred_GBR))
print('Mean Squared Error:- ',mean_squared_error(y_test, pred_GBR))
print("Root Mean Squared Error:- ",np.sqrt(mean_squared_error(y_test, pred_GBR)))
# Out:
# R2_score:  0.9694956476863993
# R2_score on training data:-  99.68834850853158
# Mean Absolute Error:-  0.0877761253977603
# Mean Squared Error:-  0.012976915447716154
# Root Mean Squared Error:-  0.11391626507095531

# %%
LA = Lasso()
LA.fit(x_train, y_train)
pred_LA = LA.predict(x_test)
pred_train = LA.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_LA))
print('R2_score on training data:- ',r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:- ',mean_absolute_error(y_test, pred_LA))
print('Mean Squared Error:- ',mean_squared_error(y_test, pred_LA))
print("Root Mean Squared Error:- ",np.sqrt(mean_squared_error(y_test, pred_LA)))
# Out:
# R2_score:  -0.00012968564107329605
# R2_score on training data:-  0.0
# Mean Absolute Error:-  0.551344436673078
# Mean Squared Error:-  0.42546710167415974
# Root Mean Squared Error:-  0.6522783927696515

# %%
RD = Ridge()
RD.fit(x_train, y_train)
pred_RD = LR.predict(x_test)
pred_train = RD.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_RD))
print('R2_score on training data:- ',r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:- ',mean_absolute_error(y_test, pred_RD))
print('Mean Squared Error:- ',mean_squared_error(y_test, pred_RD))
print("Root Mean Squared Error:- ",np.sqrt(mean_squared_error(y_test, pred_RD)))
# Out:
# R2_score:  0.9307840072015574
# R2_score on training data:-  91.52317792809856
# Mean Absolute Error:-  0.12561363379644272
# Mean Squared Error:-  0.029445309211651182
# Root Mean Squared Error:-  0.171596355473102

# %%
DTR = DecisionTreeRegressor()
DTR.fit(x_train, y_train)
pred_DTR = DTR.predict(x_test)
pred_train = DTR.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_DTR))
print('R2_score on training data:- ',r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:- ',mean_absolute_error(y_test, pred_DTR))
print('Mean Squared Error:- ',mean_squared_error(y_test, pred_DTR))
print("Root Mean Squared Error:- ",np.sqrt(mean_squared_error(y_test, pred_DTR)))
# Out:
# R2_score:  0.8734275642344924
# R2_score on training data:-  100.0
# Mean Absolute Error:-  0.1714825581395349
# Mean Squared Error:-  0.05384542441860467
# Root Mean Squared Error:-  0.23204616872209863

# %%
from sklearn.svm import SVR
svr = SVR()
svr.fit(x_train, y_train)
pred_svr = svr.predict(x_test)
pred_train = svr.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_svr))
print('R2_score on training data:- ',r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:- ',mean_absolute_error(y_test, pred_svr))
print('Mean Squared Error:- ',mean_squared_error(y_test, pred_svr))
print("Root Mean Squared Error:- ",np.sqrt(mean_squared_error(y_test, pred_svr)))
# Out:
# R2_score:  0.9414520592090856
# R2_score on training data:-  98.33743270742904
# Mean Absolute Error:-  0.09333721911107036
# Mean Squared Error:-  0.0249069925979984
# Root Mean Squared Error:-  0.15781949371987733

# %%
from sklearn.ensemble import ExtraTreesRegressor
ETR = ExtraTreesRegressor()
ETR.fit(x_train, y_train)
pred_ETR = ETR.predict(x_test)
pred_train = ETR.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_ETR))
print('R2_score on training data:- ',r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:- ',mean_absolute_error(y_test, pred_ETR))
print('Mean Squared Error:- ',mean_squared_error(y_test, pred_ETR))
print("Root Mean Squared Error:- ",np.sqrt(mean_squared_error(y_test, pred_ETR)))
# Out:
# R2_score:  0.9629550152393762
# R2_score on training data:-  100.0
# Mean Absolute Error:-  0.0921338372093022
# Mean Squared Error:-  0.015759378532558103
# Root Mean Squared Error:-  0.12553636338749863

# %% [markdown]
# # Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score

# %%
# Checking cv score for LinearRegression
score = cross_val_score(LR, x, y)
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is - ", r2_score(y_test, pred_LR) - score.mean())
# Out:
# [0.92913339 0.79599437 0.87272954 0.91202329 0.60842672]
# 0.8236614600965648
# Difference between R2 score and cross validation score is -  0.10712254710499258

# %%
# Checking cv score for RandomForestRegression
score1 = cross_val_score(RFR, x, y)
print(score1)
print(score1.mean())
print("Difference between R2 score and cross validation score is - ", r2_score(y_test, pred_RFR) - score1.mean())
# Out:
# [0.95487261 0.88930991 0.9583835  0.93697055 0.93986234]
# 0.9358797804521345
# Difference between R2 score and cross validation score is -  0.020918917666840287

# %%
# Checking cv score for KNeighborsRegressor
score2 = cross_val_score(KNN, x, y)
print(score2)
print(score2.mean())
print("Difference between R2 score and cross validation score is - ", r2_score(y_test, pred_KNN) - score2.mean())
# Out:
# [0.94607309 0.84729891 0.92077634 0.92416498 0.93414447]
# 0.9144915575761285
# Difference between R2 score and cross validation score is -  0.03222692391523441

# %%
# Checking cv score for GradientBoostingRegressor
score3 = cross_val_score(GBR, x, y)
print(score3)
print(score3.mean())
print("Difference between R2 score and cross validation score is - ", r2_score(y_test, pred_GBR) - score3.mean())
# Out:
# [0.97168076 0.93741044 0.96432422 0.95304847 0.96097906]
# 0.9574885905425606
# Difference between R2 score and cross validation score is -  0.01200705714383865

# %%
# Checking cv score for Lasso
score4 = cross_val_score(LA, x, y)
print(score4)
print(score4.mean())
print("Difference between R2 score and cross validation score is - ", r2_score(y_test, pred_LA) - score4.mean())
# Out:
# [-0.00643799 -0.0037979  -0.00364638 -0.00242138 -0.02411396]
# -0.008083520623131602
# Difference between R2 score and cross validation score is -  0.007953834982058306

# %%
# Checking cv score for Ridge
score5 = cross_val_score(RD, x, y)
print(score5)
print(score5.mean())
print("Difference between R2 score and cross validation score is - ", r2_score(y_test, pred_RD) - score5.mean())
# Out:
# [0.92924333 0.79581003 0.87333048 0.91230781 0.61644954]
# 0.8254282398879411
# Difference between R2 score and cross validation score is -  0.10535576731361629

# %%
# Checking cv score for DecisionTreesRegressor
score6 = cross_val_score(DTR, x, y)
print(score6)
print(score6.mean())
print("Difference between R2 score and cross validation score is - ", r2_score(y_test, pred_DTR) - score6.mean())
# Out:
# [0.77168775 0.80713112 0.87966215 0.83544535 0.76466166]
# 0.8117176087571101
# Difference between R2 score and cross validation score is -  0.06170995547738234

# %%
# Checking cv score for SVR
score7 = cross_val_score(svr, x, y)
print(score7)
print(score7.mean())
print("Difference between R2 score and cross validation score is - ", r2_score(y_test, pred_svr) - score7.mean())
# Out:
# [0.92421732 0.92577017 0.9130693  0.96872874 0.8889072 ]
# 0.9241385464165859
# Difference between R2 score and cross validation score is -  0.017313512792499708

# %%
# Checking cv score for ETR
score8 = cross_val_score(ETR, x, y)
print(score8)
print(score8.mean())
print("Difference between R2 score and cross validation score is - ", r2_score(y_test, pred_ETR) - score8.mean())
# Out:
# [0.96990366 0.9094854  0.96188395 0.95546966 0.9421693 ]
# 0.9477823927456107
# Difference between R2 score and cross validation score is -  0.015172622493765497

# %%
# Checking cv score for SVR
score7 = cross_val_score(svr, x, y)
print(score7)
print(score7.mean())
print("Difference between R2 score and cross validation score is - ", r2_score(y_test, pred_svr) - score7.mean())
# Out:
# [0.92421732 0.92577017 0.9130693  0.96872874 0.8889072 ]
# 0.9241385464165859
# Difference between R2 score and cross validation score is -  0.017313512792499708

# %% [markdown]
# # Gradient Boosting Regressor is our best Model

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param = {'n_estimators':[500,1000,2000],
         'learning_rate':[.001,0.01,.1],
         'max_depth':[1,2,4],
         'subsample':[.5,.75,1],
         'random_state':[1]}

# %%
gscv = GridSearchCV(GradientBoostingRegressor(), param, cv = 5)

# %%
gscv.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.001, 0.01, 0.1],
#                          'max_depth': [1, 2, 4],
#                          'n_estimators': [500, 1000, 2000], 'random_state': [1],
#                          'subsample': [0.5, 0.75, 1]})

# %%
gscv.best_params_
# Out:
# {'learning_rate': 0.01,
#  'max_depth': 2,
#  'n_estimators': 2000,
#  'random_state': 1,
#  'subsample': 0.5}

# %%
Model = GradientBoostingRegressor(learning_rate = 0.01, max_depth = 2, n_estimators = 2000, random_state =1, subsample = 0.5)

# %%
Model.fit(x_train, y_train)
print('R2 score: - ', r2_score(y_test, pred))
print('Mean Absolute Error: - ', mean_absolute_error(y_test, pred))
print('Mean Squared error: - ', mean_squared_error(y_test, pred))
print("Root Mean Squared Error: - ",np.sqrt(mean_squared_error(y_test, pred)))
# Out:
# R2 score: -  -0.6114836277594538
# Mean Absolute Error: -  0.666139405632391
# Mean Squared error: -  0.6855443632379445
# Root Mean Squared Error: -  0.8279760644112513

# %% [markdown]
# # Saving the model

# %%
import joblib
joblib.dump(Model, "Student grades prediction.pki")
# Out:
# ['Student grades prediction.pki']

# %% [markdown]
# # Predicting the saved model

# %%
import pickle
filename = "Student grades prediction.pki"
pickle.dump(Model, open(filename, 'wb'))

# %%
import pickle
loaded_model = pickle.load(open("Student grades prediction.pki", 'rb'))
result = loaded_model.score(x_test, y_test)
print(result*100)
# Out:
# 97.671130216657
